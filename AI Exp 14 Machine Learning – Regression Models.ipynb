# %%
# ✅ Install required packages
# !pip install matplotlib scikit-learn --quiet

# ✅ Import required libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# ✅ Generate sample data
np.random.seed(0)
X = np.arange(1, 10).reshape(-1, 1)
y = np.array([1.2, 1.9, 3.2, 4.1, 6.8, 8.5, 10.1, 12.9, 15.3])

# %%
# ✅ Task 1: Linear Regression
# Fit linear model
lin_reg = LinearRegression()
lin_reg.fit(X, y)

# Predict and plot
y_pred_lin = lin_reg.predict(X)
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, y_pred_lin, color='red', label='Linear Fit')
plt.title('Linear Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %%
# ✅ Task 2: Polynomial Regression
# Transform features to polynomial
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# Fit polynomial model
poly_reg = LinearRegression()
poly_reg.fit(X_poly, y)

# Predict and plot
y_pred_poly = poly_reg.predict(X_poly)
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, y_pred_poly, color='green', label='Polynomial Fit (degree=2)')
plt.title('Polynomial Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %%
# ✅ Compare R² scores
print("🔹 R² Score (Linear Regression):", r2_score(y, y_pred_lin))
print("🔹 R² Score (Polynomial Regression):", r2_score(y, y_pred_poly))
# Out:
# 🔹 R² Score (Linear Regression): 0.9746136146809585
# 🔹 R² Score (Polynomial Regression): 0.9962616731155931
